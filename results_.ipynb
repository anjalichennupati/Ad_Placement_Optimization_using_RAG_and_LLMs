# %%
from langchain_community.document_loaders import PyPDFDirectoryLoader
loader = PyPDFDirectoryLoader("files/")
docs = loader.load()

# %%
docs
# Out:
# [Document(page_content=' \n   \n   \n2.1.1  Introduction  \nThe advertising of Coca -Cola has historically been among the most ingenious and creative in \nthe marketing history. They integrated component of mass media used by Coca -Cola includes \ntelevision advertising, banner ads, print advertising, direct marketing, w eb based interactive, \nsales promotion, social media marketing and experience based marketing.  \nIn 2011, Coca Cola completed 125 years. They wanted to celebrate their anniversary by doing \nsomething different that was never tried before along with their coverage of traditional and digital mediums. Obscura Digital, a San Francisco -based technology lab and creative agency \ndesigned and executed something which was really impressive!!!  \nOn May 6, 2011, the Coca -Cola headquarters tower (a 26 -story tall building) in  Atlanta was \nilluminated, showcasing a spectacular vision of the glorious 125 years and a “Thank You” \nmessage for millions of customers who made
# ...

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=300)
documents=text_splitter.split_documents(docs)
documents[:5]
# Out:
# [Document(page_content='2.1.1  Introduction  \nThe advertising of Coca -Cola has historically been among the most ingenious and creative in \nthe marketing history. They integrated component of mass media used by Coca -Cola includes \ntelevision advertising, banner ads, print advertising, direct marketing, w eb based interactive, \nsales promotion, social media marketing and experience based marketing.  \nIn 2011, Coca Cola completed 125 years. They wanted to celebrate their anniversary by doing', metadata={'source': 'files\\ad_pdf.pdf', 'page': 0}),
# ...

# %%
import os

os.environ["COHERE_API_KEY"] = "YOUR COHERE API KEY"

# %%
import cohere
co = cohere.Client('YOUR COHERE API KEY')

faq_questions=[
     "How much is a burger?",
     "When do you close?",
     "What are the hours",
     "Do you have vegan options",
     "What is the closest route"]

response=co.embed(texts=faq_questions, input_type="search_query", model="embed-english-v3.0")
print('Embeddings: {}'.format(response.embeddings))
# Out:
# Embeddings: [[0.00056934357, 0.0010328293, 0.012214661, 0.021255493, -0.017959595, 0.008598328, 0.012390137, -0.024902344, -0.033721924, 0.015556335, -0.028671265, 0.025878906, 0.0011882782, -0.006954193, 0.046051025, -0.0234375, 0.028640747, 0.028686523, 0.039489746, 0.011009216, 0.00062561035, 0.02961731, 0.03567505, 0.005115509, 0.105529785, -0.06774902, -0.031402588, 0.005466461, 0.06604004, 0.0015640259, 0.008140564, -0.03564453, 0.00027298927, -0.030960083, 0.072753906, 0.032989502, -0.0012235641, -0.0042686462, 0.032684326, -0.00945282, 0.049224854, -0.030166626, -0.033111572, -0.026382446, -0.032714844, -0.009841919, 0.023590088, -0.0063972473, 0.015029907, 0.011428833, -0.006641388, 0.007965088, 0.0027008057, -0.014328003, -0.0044517517, -0.002401352, 0.052764893, -0.07647705, 0.019317627, -0.0018444061, -0.0028324127, 0.045013428, 0.02558899, 0.0040779114, 0.010406494, 0.0020580292, 0.064575195, 0.0042686462, 0.033081055, -0.0040779114, -0.018447876, 0.045898438, 0.01757812
# ...

# %%
from langchain_cohere import CohereEmbeddings

embeddings_model = CohereEmbeddings(cohere_api_key="YOUR COHERE API KEY")

# %%
documents
# Out:
# [Document(page_content='2.1.1  Introduction  \nThe advertising of Coca -Cola has historically been among the most ingenious and creative in \nthe marketing history. They integrated component of mass media used by Coca -Cola includes \ntelevision advertising, banner ads, print advertising, direct marketing, w eb based interactive, \nsales promotion, social media marketing and experience based marketing.  \nIn 2011, Coca Cola completed 125 years. They wanted to celebrate their anniversary by doing', metadata={'source': 'files\\ad_pdf.pdf', 'page': 0}),
# ...

# %%
# %pip install langchain_chroma
# Out:
# ...
#      ------------------------------------ 525.5/525.5 kB 622.2 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 3.3/3.3 MB 976.4 kB/s eta 0:00:00
# ...
#   Attempting uninstall: chromadb
#     Found existing installation: chromadb 0.5.0
#     Uninstalling chromadb-0.5.0:
#       Successfully uninstalled chromadb-0.5.0
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_chroma import Chroma
from langchain_community.embeddings import OllamaEmbeddings
embeddings_ollama = OllamaEmbeddings(model="llama3")
db_o = Chroma.from_documents(documents[:100], embeddings_ollama)

# %%
documents[:30]
# Out:
# [Document(page_content='2.1.1  Introduction  \nThe advertising of Coca -Cola has historically been among the most ingenious and creative in \nthe marketing history. They integrated component of mass media used by Coca -Cola includes \ntelevision advertising, banner ads, print advertising, direct marketing, w eb based interactive, \nsales promotion, social media marketing and experience based marketing.  \nIn 2011, Coca Cola completed 125 years. They wanted to celebrate their anniversary by doing', metadata={'source': 'files\\ad_pdf.pdf', 'page': 0}),
# ...

# %%
query="Product advertising"
result=db_o.similarity_search_with_relevance_scores(query)
# Out:
# c:\Users\jasvi\OneDrive\Desktop\sem6\project_mcd\venv\Lib\site-packages\langchain_core\vectorstores.py:330: UserWarning: Relevance scores must be between 0 and 1, got [(Document(page_content='as they are charged based on per line. These are not widespread as large display ads. They do \nnot include any graphics.  \n \nFigure 2.1.2: An Example of Class ified Advertising  \n \nFigure 2.1.3: Another Example of Classified Advertising  \n(ii) Display Advertising  \nDisplay advertising basically appears in websites. These advertisements can be in different formats and they have items such as text, images, flash, audio, vide os etc. The first banner', metadata={'page': 2, 'source': 'files\\ad_pdf.pdf'}), -14247.657393326494), (Document(page_content='shares a certain percentage of the member’s advertising. It can also be an agreement between two or more marketers who have complementary products (such as footwear and socks) or different seasonal sales cycles (such as winter co ats and raincoa
# ...

# %%
result
# Out:
# [(Document(page_content='as they are charged based on per line. These are not widespread as large display ads. They do \nnot include any graphics.  \n \nFigure 2.1.2: An Example of Class ified Advertising  \n \nFigure 2.1.3: Another Example of Classified Advertising  \n(ii) Display Advertising  \nDisplay advertising basically appears in websites. These advertisements can be in different formats and they have items such as text, images, flash, audio, vide os etc. The first banner', metadata={'page': 2, 'source': 'files\\ad_pdf.pdf'}),
#   -14247.657393326494),
# ...

# %%
query="brand loyalty"
result=db_o.similarity_search_with_relevance_scores(query)
result
# Out:
# c:\Users\jasvi\OneDrive\Desktop\sem6\project_mcd\venv\Lib\site-packages\langchain_core\vectorstores.py:330: UserWarning: Relevance scores must be between 0 and 1, got [(Document(page_content='as they are charged based on per line. These are not widespread as large display ads. They do \nnot include any graphics.  \n \nFigure 2.1.2: An Example of Class ified Advertising  \n \nFigure 2.1.3: Another Example of Classified Advertising  \n(ii) Display Advertising  \nDisplay advertising basically appears in websites. These advertisements can be in different formats and they have items such as text, images, flash, audio, vide os etc. The first banner', metadata={'page': 2, 'source': 'files\\ad_pdf.pdf'}), -18683.468052095315), (Document(page_content='o Global advertising is a communication strategy where a company employs to drive demands for its goods and services in international or global markets. Global advertising strategies are adapted and tailor -made to suit the cultural \ndifference
# ...

# %%
from langchain_community.vectorstores import FAISS

db=FAISS.from_documents(documents[:30],embeddings_model)

# %%
from langchain_community.embeddings import OllamaEmbeddings
db1=FAISS.from_documents(documents[:30],OllamaEmbeddings())

# %%
# %pip install --upgrade --quiet  langchain-google-genai
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
os.environ["GOOGLE_API_KEY"] = "AIzaSyCttLpNFmko-APMWifDBb4V3lBvjfQ2dG8"

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

embeddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001", task_type="retrieval_document")

# %%
db_google=FAISS.from_documents(documents[:30],embeddings)

# %%
query="Give some local advertising strategies?"
result=db_google.similarity_search_with_relevance_scores(query)
result
# Out:
# [(Document(page_content='Advertising is a complex form of communication. Businesses have found many different ways \nto communicate their message to the consumer. Modern advertiser s have an array of choices \nat their disposal. The Internet alone provides many options to the advertisers to reach out to their prospective customers. The most suitable advertising choice depends on the target audience and the most cost- effective way to reach them. For instance, if a company knows', metadata={'source': 'files\\ad_pdf.pdf', 'page': 1}),
#   0.6351891861694665),
# ...

# %%
# %pip install infinity_emb[torch,optimum]
# Out:
# ...
#      -------------------------------------- 56.0/56.0 kB 365.7 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.3/1.3 MB 1.5 MB/s eta 0:00:00
# ...
#      -------------------------------------- 417.0/417.0 kB 1.6 MB/s eta 0:00:00
# ...
#   Using cached sentence_transformers-2.7.0-py3-none-any.whl (171 kB)
# ...
#      -------------------------------------- 198.6/198.6 MB 1.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 9.0/9.0 MB 1.7 MB/s eta 0:00:00
# ...
#      -------------------------------------- 542.0/542.0 kB 1.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 14.4/14.4 MB 1.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 84.1/84.1 kB 4.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 10.6/10.6 MB 1.9 MB/s eta 0:00:00
# ...
#   Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# ...
#   Using cached xxhash-3.4.1-cp311-cp311-win_amd64.whl (29 kB)
# ...
#   Using cached multiprocess-0.70.16-py311-none-any.whl (143 kB)
# ...

# %%
from langchain_community.embeddings import InfinityEmbeddings, InfinityEmbeddingsLocal

# %%
embeddings = InfinityEmbeddingsLocal(
    model="sentence-transformers/all-MiniLM-L6-v2",
    # revision
    revision=None,
    # best to keep at 32
    batch_size=32,
    # for AMD/Nvidia GPUs via torch
    device="cuda",
    # warm up model before execution
)


async def embed():
    # TODO: This function is just to showcase that your call can run async.

    # important: use engine inside of `async with` statement to start/stop the batching engine.
    async with embeddings:
        # avoid closing and starting the engine often.
        # rather keep it running.
        # you may call `await embeddings.__aenter__()` and `__aexit__()
        # if you are sure when to manually start/stop execution` in a more granular way

        documents_embedded = await embeddings.aembed_documents(documents)
        query_result = await embeddings.aembed_query(query)
        print("embeddings created successful")
    return documents_embedded, query_result
documents_embedded, query_result = await embed()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 embeddings = InfinityEmbeddingsLocal(
#       2     model="sentence-transformers/all-MiniLM-L6-v2",
#       3     # revision
#       4     revision=None,
#       5     # best to keep at 32
#       6     batch_size=32,
#       7     # for AMD/Nvidia GPUs via torch
#       8     device="cuda",
#       9     # warm up model before execution
#      10 )
#      13 async def embed():
#      14     # TODO: This function is just to showcase that your call can run async.
#      15
#      16     # important: use engine inside of `async with` statement to start/stop the batching engine.
#      17     async with embeddings:
#      18         # avoid closing and starting the engine often.
#      19         # rather keep it running.
#      20         # you may call `await embeddings.__aenter__()` and `__aexit__()
# ...

# %%
# %pip install --upgrade --quiet  boto3
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_community.embeddings import BedrockEmbeddings

embeddings = BedrockEmbeddings(
    credentials_profile_name="637423344532", region_name="us-east-1"
)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[5], line 3
#       1 from langchain_community.embeddings import BedrockEmbeddings
# ----> 3 embeddings = BedrockEmbeddings(
#       4     credentials_profile_name="637423344532", region_name="us-east-1"
#       5 )
#
# File c:\Users\jasvi\OneDrive\Desktop\sem6\project_mcd\venv\Lib\site-packages\pydantic\v1\main.py:341, in BaseModel.__init__(__pydantic_self__, **data)
#     339 values, fields_set, validation_error = validate_model(__pydantic_self__.__class__, data)
#     340 if validation_error:
# --> 341     raise validation_error
#     342 try:
#     343     object_setattr(__pydantic_self__, '__dict__', values)
#
# ValidationError: 1 validation error for BedrockEmbeddings
# __root__
# ...

# %%
db

# %%
query="when did Coca Cola complete 125 years?"
result=db.similarity_search(query)
result
# Out:
# [Document(page_content='illuminated, showcasing a spectacular vision of the glorious 125 years and a “Thank You” \nmessage for millions of customers who made it happen.  \nCoca -Cola celebrated their anniversary in style.  \nA few interesting facts about the massive campaign  for Coke’s 125th year are given below:  \n1. The event projected the imagery from a library of 125 years of Coke’s advertising, \nalong with the iconic Coke bottle featured in 3D across the 26 stories of the building.', metadata={'source': 'files\\ad_pdf.pdf', 'page': 0}),
# ...

# %%
db.similarity_search_with_relevance_scores(query)
# Out:
# c:\Users\jasvi\OneDrive\Desktop\sem6\project_mcd\venv\Lib\site-packages\langchain_core\vectorstores.py:330: UserWarning: Relevance scores must be between 0 and 1, got [(Document(page_content='illuminated, showcasing a spectacular vision of the glorious 125 years and a “Thank You” \nmessage for millions of customers who made it happen.  \nCoca -Cola celebrated their anniversary in style.  \nA few interesting facts about the massive campaign  for Coke’s 125th year are given below:  \n1. The event projected the imagery from a library of 125 years of Coke’s advertising, \nalong with the iconic Coke bottle featured in 3D across the 26 stories of the building.', metadata={'source': 'files\\ad_pdf.pdf', 'page': 0}), -3246.636139559997), (Document(page_content='designed and executed something which was really impressive!!!  \nOn May 6, 2011, the Coca -Cola headquarters tower (a 26 -story tall building) in  Atlanta was \nilluminated, showcasing a spectacular vision of the glorious 125 years a
# ...

# %%
query1="Give interesting facts about the massive campaign for Coke’s 125th year?"
result=db1.similarity_search(query)
result
# Out:
# [Document(page_content='Through digital advertising, campaigns can reach a large set of target audience. It is not only a \ncost-effective medium of communication but also has a higher return over investment. \nBusinesse s scale at a faster pace through digital advertising. Digital marketers should \npromptly respond and initiate dynamic customer interactions and extract value from big data \nto make better decisions faster. Digital advertising gives the flexibility to the mar keters to \ncommunicate with customers wherever and however customers are most receptive to messages.  \n \n \nSelf-assessment Questions  \n5) _________refers to advertisements which are published in magazines or newspapers.  \na) Digital media advertising  b) Periodical advertising \nc) Outdoor advertising   d) Broadcast media advertising  \n \n6) _____________includes televisions and radio advertising.  \na) Outdoor advertising   b) Digital media advertising   \nc) Broadcast media advertising   d) Periodical 
# ...

# %%
db1.similarity_search_with_relevance_scores(query)
# Out:
# c:\Users\jasvi\OneDrive\Desktop\sem6\project_mcd\venv\Lib\site-packages\langchain_core\vectorstores.py:330: UserWarning: Relevance scores must be between 0 and 1, got [(Document(page_content='Through digital advertising, campaigns can reach a large set of target audience. It is not only a \ncost-effective medium of communication but also has a higher return over investment. \nBusinesse s scale at a faster pace through digital advertising. Digital marketers should \npromptly respond and initiate dynamic customer interactions and extract value from big data \nto make better decisions faster. Digital advertising gives the flexibility to the mar keters to \ncommunicate with customers wherever and however customers are most receptive to messages.  \n \n \nSelf-assessment Questions  \n5) _________refers to advertisements which are published in magazines or newspapers.  \na) Digital media advertising  b) Periodical advertising \nc) Outdoor advertising   d) Broadcast media advertising  \n \n
# ...

# %%
result[0].page_content
# Out:
# 'CHAPTER 1\nIndustry and Market\nWhen developing an assessment of the market and the industry, it is \nimportant to take a macroview of the market and identify the job that \nconsumers need done. This chapter focuses on information that is needed \non the industry and the market in which a company plans to focus its \nstrategic marketing efforts.\nTheodore Levitt’s seminal work on marketing myopia stated that \nrailroads were not in trouble in the 1970s because the need for moving \n people and products had diminished. Railroads were in trouble because \nthey viewed themselves as being in the railroad business instead of being \nin the transportation business. \nUsing Clayton Christensen’s theories on disruptive innovation, new \nforms of transporting people and products were not a disruptive innova -\ntion focused on providing the railroad’s least profitable customers with a \n“good enough” product. Rather, these new forms of transportation were'

# %%
len(documents)
# Out:
# 55

# %%
from langchain_community.llms import Ollama
llm= Ollama(model="llama2")

# %%
llm
# Out:
# Ollama()

# %%
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_template("""
Answer the following question based only on the provided context. 
Think step by step before providing a detailed answer. 
I will tip you $1000 if the user finds the answer helpful. 
<context>
{context}
</context>
Question: {input}""")

# %%
from langchain.chains.combine_documents import create_stuff_documents_chain
document_chain=create_stuff_documents_chain(llm,prompt)
#check doc chain for report

# %%
retriever= db.as_retriever()
retriever
# Out:
# VectorStoreRetriever(tags=['FAISS', 'OpenAIEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x000001200B40DB10>)

# %%
#creating a retreiver chain
from langchain.chains import create_retrieval_chain
retrieval_chain= create_retrieval_chain(retriever, document_chain)

# %%
response=retrieval_chain.invoke({"input":"Explain clearly about National Advertising?"})

# %%
response['answer']
# Out:
# "National advertising is a type of advertising that is not confined to any specific geographical area within a nation. It is designed to inform and remind consumers about a brand and company on a mass scale. The objective of national advertising is to communicate the features, benefits, and uses of a brand to a wide audience. National advertisements are typically broadcasted through various media channels such as television, radio, newspapers, magazines, billboards, and the Internet.\n\nNational advertising is usually carried out by large and well-funded companies such as Coke, Pepsi, Procter & Gamble, Johnson & Johnson, etc. These companies identify a specific target audience and build a brand image through national advertising. They may also introduce new brands or emphasize on brand loyalty for established ones through this type of advertising.\n\nNational advertising can be expensive, but it provides an opportunity to reach a large number of people simultaneously, increasing the 
# ...

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-3.5-turbo-0125", temperature=0)
from langchain.chains.combine_documents import create_stuff_documents_chain
document_chain=create_stuff_documents_chain(llm,prompt)
retriever= db.as_retriever()
retrieval_chain= create_retrieval_chain(retriever, document_chain)
response=retrieval_chain.invoke({"input":"Explain clearly about National Advertising?"})
response['answer']
# Out:
# "National advertising is a type of advertising that is not limited to a specific geographical area within a nation. It involves mass marketing efforts aimed at informing and reminding consumers about a brand and company. The main objective of national advertising is to communicate the features, benefits, and uses of the brand to a wide audience. \n\nNational advertisements are typically broadcasted on various platforms such as television, radio, newspapers, magazines, billboards, and the Internet. This type of advertising is usually carried out by large and well-funded companies like Coke, Pepsi, Procter & Gamble, Johnson & Johnson, etc. These companies identify a specific target audience and work on building a brand image through national advertising.\n\nNational advertising can also involve the introduction of new brands and the emphasis on brand loyalty for established ones. It is an expensive affair due to the wide reach and various platforms used for broadcasting. Overall, natio
# ...

# %%
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_template("""
Answer the following question based only on the provided context. 
Think step by step before providing a detailed answer. 
I will tip you $1000 if the user finds the answer helpful. 
<context>
{context}
</context>
Question: {input}""")

# %%
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_template("""
Answer the following question based only on the provided context. 
Think step by step before providing a detailed answer. 
I will tip you $1000 if the user finds the answer helpful. 
<context>
{context}
</context>
Question: {input}""")
